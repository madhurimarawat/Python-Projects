# %% [markdown]
# # Data Visualization on Automobile Dataset
#
# ## In this data visualization of Automobile Dataset is done

# %% [markdown]
# ## Loading CSV file and all required libraries for data analysis and data visualization

# %%
# Importing required Libraries

# Importing pandas to read csv file and for data manipulation
import pandas as pd

# Importing matplotlib to provide axis labels and titles to the plot
import matplotlib.pyplot as plt

# Importing seaborn for plotting
import seaborn as sns

# Importing csv file using pandas
df = pd.read_csv("/content/Automobile.csv")

# Printing dataframe
print("Dataframe is:\n")
print(df)
# Out:
# Dataframe is:
#
#           company   body-style  length engine  mileage sunroof
# 0     alfa-romero  convertible   168.8   dohc       21      No
# 1     alfa-romero    hatchback   171.2   dohc       19      No
# 2            audi        sedan   176.6    ohc       24     Yes
# 3            audi        sedan   176.6   None       18     Yes
# 4            audi        sedan   177.3    ohc       19     Yes
# 5            audi        wagon   192.7    ohc       19     Yes
# 6             bmw        sedan   176.8    ohc       23     Yes
# 7             bmw        sedan   176.8    ohc       23     Yes
# 8             bmw        sedan   176.8    ohc       21     Yes
# 9             bmw        sedan   189.0    ohc       16     Yes
# 10            bmw        sedan   193.8    ohc       16     Yes
# 11            bmw        sedan   197.0    ohc       15     Yes
# 12      chevrolet    hatchback   141.1    ohc       47      No
# 13      chevrolet    hatchback   155.9    ohc       38      No
# ...

# %%
# Seeing first 7 rows of dataframe using head() function
print("First Seven Rows of dataset are:\n")
df.head(7)
# Out:
# First Seven Rows of dataset are:
#        company   body-style  length engine  mileage sunroof
# 0  alfa-romero  convertible   168.8   dohc       21      No
# 1  alfa-romero    hatchback   171.2   dohc       19      No
# 2         audi        sedan   176.6    ohc       24     Yes
# 3         audi        sedan   176.6   None       18     Yes
# 4         audi        sedan   177.3    ohc       19     Yes
# 5         audi        wagon   192.7    ohc       19     Yes
# 6          bmw        sedan   176.8    ohc       23     Yes

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ## Looking at the columns of dataset

# %%
# Seeing columns of the dataset
print("Columns of Dataset are: ")
print(df.columns)
# Out:
# Columns of Dataset are:
# Index(['company', 'body-style', 'length', 'engine', 'mileage', 'sunroof'], dtype='object')

# %% [markdown]
# ## Unique Categories in dataset

# %%
# Seeing total unique companies in the dataset
print("\nTotal Unique Companies in Dataset are:", df['company'].nunique())

unique_companies = df['company'].unique()
print("\nUnique companies in the dataset:\n")
print(unique_companies)

# Seeing total unique body style in the dataset
print("\nTotal Unique Body Style in Dataset are:", df['body-style'].nunique())

unique_body_style = df['body-style'].unique()
print("\nUnique Body Style in the dataset:\n")
print(unique_body_style)

# Seeing total unique engine in the dataset
print("\nTotal Unique Engine in Dataset are:", df['engine'].nunique())

unique_engine = df['engine'].unique()
print("\nUnique Engine in the dataset:\n")
print(unique_engine)
# Out:
# Total Unique Companies in Dataset are: 16
#
# Unique companies in the dataset:
#
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mitsubishi' 'nissan' 'porsche' 'toyota'
#  'volkswagen' 'volvo']
#
# Total Unique Body Style in Dataset are: 5
#
# Unique Body Style in the dataset:
#
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
#
# Total Unique Engine in Dataset are: 7
#
# Unique Engine in the dataset:
#
# ['dohc' 'ohc' 'None' 'ohcv' 'rotor' 'ohcf' 'dohcv']

# %% [markdown]
# ## Looking for missing values

# %%
# Seeing missing values
print("Missing values in dataset are:\n")
df.isnull().sum()
# Out:
# Missing values in dataset are:
# company       0
# body-style    0
# length        0
# engine        0
# mileage       0
# sunroof       0
# dtype: int64

# %% [markdown]
# ## No Missing data so we will now see the descriptive statistics of dataset

# %%
# Also seeing for string data
print("Descriptive Statistics of Datset is:\n")
df.describe(include = 'all')
# Out:
# Descriptive Statistics of Datset is:
#        company body-style      length engine    mileage sunroof
# count       60         60   60.000000     60  60.000000      60
# unique      16          5         NaN      7        NaN       2
# top     toyota      sedan         NaN    ohc        NaN     Yes
# freq         7         32         NaN     46        NaN      33
# mean       NaN        NaN  173.170000    NaN  25.883333     NaN
# std        NaN        NaN   14.128914    NaN   8.174146     NaN
# min        NaN        NaN  141.100000    NaN  13.000000     NaN
# 25%        NaN        NaN  159.100000    NaN  19.000000     NaN
# 50%        NaN        NaN  171.450000    NaN  25.000000     NaN
# 75%        NaN        NaN  179.125000    NaN  31.000000     NaN
# max        NaN        NaN  208.100000    NaN  47.000000     NaN

# %% [markdown]
# ## Data Visualization on Dataset

# %% [markdown]
# ## Plotting line graph between Length and Mileage with engine as the hue parameter(to understand the variation)
# ### We can see that cars with lesser length are giving more mileage and cars with more length are giving lesser mileage and the highest mileage is given by ohc engine

# %%
# Plotting line graph between Length and Mileage with engine as the hue parameter(to understand the variation)
sns.lineplot(df,x=df["length"],y=df["mileage"],hue=df["engine"])

# Adding Labels
plt.title("Length and Mileage of Automobiles wrt engine")
plt.xlabel("Length of the Automobile")
plt.ylabel("Mileage given by the Automobile")
# Out:
# Text(0, 0.5, 'Mileage given by the Automobile')

# %% [markdown]
# ## Plotting a scatter plot to visualize the data in a more clear way
# ### All points are visible in this plot
# ### Plotting scatter plot between Length and Mileage with engine as the hue parameter(to understand the variation)
# ### We can see that cars with lesser length are giving more mileage and cars with more length are giving lesser mileage and the highest mileage is given by ohc engine

# %%
# Plotting scatter plot between Length and Mileage with engine as the hue parameter(to understand the variation)
sns.scatterplot(df,x=df["length"],y=df["mileage"],hue=df["engine"])

# Adding Labels
plt.title("Length and Mileage of Automobiles wrt engine")
plt.xlabel("Length of the Automobile")
plt.ylabel("Mileage given by the Automobile")
# Out:
# Text(0, 0.5, 'Mileage given by the Automobile')

# %% [markdown]
# ## Now let's make a regression or correlation plot to understand the correlation between length and mileage
# ### With the plot it is clear that their is a negative correlation between length and mileage which implies smaller(less) length cars have more mileage and vice a versa

# %%
# Now let's make a regression or correlation plot to understand the correlation between length and mileage
sns.regplot(x ='length', y = 'mileage', data = df)

# Adding Labels
plt.title("Length and Mileage of Automobiles wrt engine")
plt.xlabel("Length of the Automobile")
plt.ylabel("Mileage given by the Automobile")
# Out:
# Text(0, 0.5, 'Mileage given by the Automobile')

# %% [markdown]
# ## Plotting scatter plot between Length and Mileage with sunroof as the hue parameter(to understand the variation)
# ### We can see that most longer cars have sunroof while smaller or compact cars do not have sunroof
# ### Also few cars are there which gives good mileage , are compact and also have sunroof
# ### Thus we can  see their is no strong relation between cars having sunroof on mileage

# %%
# Plotting scatter plot between Length and Mileage with sunroof as the hue parameter(to understand the variation)
sns.scatterplot(df,x=df["length"],y=df["mileage"],hue=df["sunroof"])

# Adding Labels
plt.title("Length and Mileage of Automobiles wrt sunroof")
plt.xlabel("Length of the Automobile")
plt.ylabel("Mileage given by the Automobile")
# Out:
# Text(0, 0.5, 'Mileage given by the Automobile')

# %% [markdown]
# ## Plotting scatter plot between Length and Mileage with body-style as the hue parameter(to understand the variation)
# ### We can see that hatchback usually come in compact(smaller) size giving good mileage while sedan and wagon provide the most variation as they come in both smaller and larger length cars and also gives good mileage.
# ### Convertible also gives good mileage in medium length
# ### hardtop usually comes in longer length and lesser mileage

# %%
# Plotting scatter plot between Length and Mileage with body-style as the hue parameter(to understand the variation)
sns.scatterplot(df,x=df["length"],y=df["mileage"],hue=df["body-style"])

# Adding Labels
plt.title("Length and Mileage of Automobiles wrt body-style")
plt.xlabel("Length of the Automobile")
plt.ylabel("Mileage given by the Automobile")
# Out:
# Text(0, 0.5, 'Mileage given by the Automobile')

# %% [markdown]
# ## Plotting relation plot between Length and Mileage with body-style and sunroof as the hue parameter(to understand the variation)
# ### From the plot we can see that sedans body style contains the most sunroof
# ### That is we can say that most sedans come with sunroof
# ### Thus we can see that though body style has effect on mileage ,their is no such case with sunroof

# %%
# Plotting relation plot between Length and Mileage with body-style and sunroof as the hue parameter(to understand the variation)
sns.relplot(x='length',y='mileage',hue=df[['body-style','sunroof']].apply(tuple,axis=1),data=df)

# Adding Labels
plt.title("Length and Mileage of Automobiles wrt body-style and sunroof")
plt.xlabel("Length of the Automobile")
plt.ylabel("Mileage given by the Automobile")
# Out:
# Text(51.934979166666665, 0.5, 'Mileage given by the Automobile')

# %% [markdown]
# ## Plotting relation plot between Length and Mileage with body-style and sunroof as the hue parameter(to understand the variation)
# ### From the plot we can see that sedans is the most popular body style and is manufactured by most companies from luxury brands to normal brands
# ### hatchback and wagon body style are also manufactured by most companies
# ### convertible and hardtop is manufactured by few companies as they are mostly luxury vehicles made by high end companies like porsche or mercedes

# %%
# Plotting relation plot between Length and Mileage with body-style and sunroof as the hue parameter(to understand the variation)
sns.relplot(x='length',y='mileage',hue=df[['body-style','company']].apply(tuple,axis=1),data=df)

# Adding Labels
plt.title("Automobiles wrt body-style and company")
plt.xlabel("Length of the Automobile")
plt.ylabel("Mileage given by the Automobile")
# Out:
# Text(59.487118055555555, 0.5, 'Mileage given by the Automobile')

# %% [markdown]
# ## Plotting relation plot between Length and Mileage with body-style, company and sunroof as the hue parameter(to understand the variation)
# ### From the plot we can see that sedans is the most popular body style and is manufactured by most companies from luxury brands to normal brands and also most sedans contain sunroof
# ### hatchback and wagon body style are also manufactured by most companies and they usually dosen't have sunroof
# ### convertible and hardtop is manufactured by few companies as they are mostly luxury vehicles made by high end companies like porsche or mercedes and they always have sunroof

# %%
# Plotting relation plot between Length and Mileage with body-style, company and sunroof as the hue parameter(to understand the variation)
sns.relplot(x='length',y='mileage',hue=df[['body-style','company','sunroof']].apply(tuple,axis=1),data=df)

# Adding Labels
plt.title("Automobiles wrt body-style,company and sunroof")
plt.xlabel("Length of the Automobile")
plt.ylabel("Mileage given by the Automobile")
# Out:
# Text(64.26910763888888, 0.5, 'Mileage given by the Automobile')

# %% [markdown]
# ## Extracting Other Insights from this Dataset

# %%
# Grouping Dataset according to body style
df_body_style = pd.DataFrame(df.groupby("body-style"))
print("Dataframe after grouping according to Body Style of Autombile is:\n")
print(df_body_style)
# Out:
# Dataframe after grouping according to Body Style of Autombile is:
#
#              0                                                  1
# 0  convertible          company   body-style  length engine  m...
# 1      hardtop            company body-style  length engine  m...
# 2    hatchback          company body-style  length engine  mil...
# 3        sedan            company body-style  length engine  m...
# 4        wagon            company body-style  length engine  m...

# %%
# Finding Average Length and Mileage according to body-style
print("Average Length and Mileage according to body-style:\n")
print(df_body_style.mean())
# Out:
# Average Length and Mileage according to body-style:
#
#                  length    mileage
# body-style
# convertible  168.850000  19.000000
# hardtop      184.050000  15.500000
# hatchback    159.700000  30.466667
# sedan        177.884375  24.937500
# wagon        177.400000  25.444444
# <ipython-input-27-112f9b68a86f>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(df_body_style.mean())

# %% [markdown]
# ## Plotting according to body-style and mean of length and mileage

# %%
# Calculate the mean of 'length' and 'mileage' for each group
grouped_data = df.groupby(['length', 'mileage','body-style']).mean().reset_index()

# Create a bar plot
sns.barplot(x='body-style', y='length', data=grouped_data)
plt.title('Average Length by Body Style')
plt.xlabel('Body Style')
plt.ylabel('Average Length')
plt.show()

sns.barplot(x='body-style', y='mileage', data=grouped_data)
plt.title('Average Mileage by Body Style')
plt.xlabel('Body Style')
plt.ylabel('Average Mileage')
plt.show()
# Out:
# <ipython-input-30-662928601882>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_data = df.groupby(['length', 'mileage','body-style']).mean().reset_index()

# %%
# Create a bar plot
sns.boxplot(x='body-style', y='length', data=grouped_data)
plt.title('Average Length by Body Style')
plt.xlabel('Body Style')
plt.ylabel('Average Length')
plt.show()

sns.boxplot(x='body-style', y='mileage', data=grouped_data)
plt.title('Average Mileage by Body Style')
plt.xlabel('Body Style')
plt.ylabel('Average Mileage')
plt.show()

# %%
# Grouping Dataset according to company
df_company = pd.DataFrame(df.groupby("company"))
print("Dataframe after grouping according to Company of Autombile is:\n")
print(df_company)
# Out:
# Dataframe after grouping according to Company of Autombile is:
#
#                 0                                                  1
# 0     alfa-romero         company   body-style  length engine  mi...
# 1            audi    company body-style  length engine  mileage s...
# 2             bmw     company body-style  length engine  mileage ...
# 3       chevrolet        company body-style  length engine  milea...
# 4           dodge     company body-style  length engine  mileage ...
# 5           honda     company body-style  length engine  mileage ...
# 6           isuzu     company body-style  length engine  mileage ...
# 7          jaguar     company body-style  length engine  mileage ...
# 8           mazda     company body-style  length engine  mileage ...
# 9   mercedes-benz            company body-style  length engine  m...
# 10     mitsubishi         company body-style  length engine  mile...
# 11         nissan     company body-style  length engine  mileage ...
# ...

# %%
# Calculate the mean of 'length' and 'mileage' for each manufacturer
grouped_data = df.groupby('company')[['length', 'mileage']].mean().reset_index()

# Create a bar plot for average length by manufacturer
plt.figure(figsize=(10, 6))
sns.barplot(x='company', y='length', data=grouped_data)
plt.title('Average Length by Manufacturer')
plt.xlabel('Manufacturer')
plt.ylabel('Average Length')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# Create a bar plot for average mileage by manufacturer
plt.figure(figsize=(10, 6))
sns.barplot(x='company', y='mileage', data=grouped_data)
plt.title('Average Mileage by Manufacturer')
plt.xlabel('Manufacturer')
plt.ylabel('Average Mileage')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Grouping dataframe
# Grouping the data by 'company' and 'body-style', then calculate the count
grouped_data = df.groupby([ 'company','mileage','length']).size().reset_index()
print("Dataset according to company and body style is:\n")
print(grouped_data,"\n")

# Create a bar plot for average length by manufacturer
plt.figure(figsize=(10, 6))
sns.boxplot(x='company', y='length', data=grouped_data)
plt.title('Average Length by Manufacturer')
plt.xlabel('Manufacturer')
plt.ylabel('Average Length')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# Create a bar plot for average mileage by manufacturer
plt.figure(figsize=(10, 6))
sns.boxplot(x='company', y='mileage', data=grouped_data)
plt.title('Average Mileage by Manufacturer')
plt.xlabel('Manufacturer')
plt.ylabel('Average Mileage')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# Dataset according to company and body style is:
#
#           company  mileage  length  0
# 0     alfa-romero       19   171.2  1
# 1     alfa-romero       21   168.8  1
# 2            audi       18   176.6  1
# 3            audi       19   177.3  1
# 4            audi       19   192.7  1
# 5            audi       24   176.6  1
# 6             bmw       15   197.0  1
# 7             bmw       16   189.0  1
# 8             bmw       16   193.8  1
# 9             bmw       21   176.8  1
# 10            bmw       23   176.8  2
# 11      chevrolet       38   155.9  1
# 12      chevrolet       38   158.8  1
# 13      chevrolet       47   141.1  1
# 14          dodge       31   157.3  2
# 15          honda       24   175.4  1
# 16          honda       25   169.1  1
# 17          honda       30   157.1  1
# 18          isuzu       24   170.7  1
# 19          isuzu       38   155.9  2
# 20         jaguar       13   191.7  1
# 21         jaguar       15   199.6  2
# ...

# %%
# Grouping the data by 'company' and 'body-style', then calculate the count
grouped_data = df.groupby(['company', 'body-style']).size().reset_index(name='vehicle_count')
print("Dataset according to company and body style is:\n")
print(grouped_data)
# Out:
# Dataset according to company and body style is:
#
#           company   body-style  vehicle_count
# 0     alfa-romero  convertible              1
# 1     alfa-romero    hatchback              1
# 2            audi        sedan              3
# 3            audi        wagon              1
# 4             bmw        sedan              6
# 5       chevrolet    hatchback              2
# 6       chevrolet        sedan              1
# 7           dodge    hatchback              2
# 8           honda        sedan              2
# 9           honda        wagon              1
# 10          isuzu        sedan              3
# 11         jaguar        sedan              3
# 12          mazda    hatchback              4
# 13          mazda        sedan              1
# 14  mercedes-benz      hardtop              1
# 15  mercedes-benz        sedan              2
# 16  mercedes-benz        wagon              1
# 17     mitsubishi    hatchback              2
# ...

# %%
# Seeing which company produces the highest number of any body-style of vehicle
max_vehicle_count = grouped_data['vehicle_count'].max()
max_vehicle_company = grouped_data[grouped_data['vehicle_count'] == max_vehicle_count]

print("Company with the highest vehicle count for a body style:\n")
print(max_vehicle_company)
# Out:
# Company with the highest vehicle count for a body style:
#
#   company body-style  vehicle_count
# 4     bmw      sedan              6

# %%
# Plotting according to company and count of vehicles produced
plt.figure(figsize=(12, 6))
sns.barplot(x='company', y='vehicle_count', hue='body-style', data=grouped_data)
plt.title('Count of Vehicles by Company and Body Style')
plt.xlabel('Company')
plt.ylabel('Vehicle Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.legend(title='Body Style', loc='upper right', bbox_to_anchor=(1.2, 1))
plt.show()

# %%
# Grouping dataframe
# Grouping the data by 'company' and 'body-style', then calculate the count
grouped_data = df.groupby(['engine', 'body-style']).size().reset_index(name='vehicle_count')
print("Dataset according to company and body style is:\n")
print(grouped_data,"\n")

# Plotting according to engine and body style
plt.figure(figsize=(12, 6))
sns.barplot(x='engine', y='vehicle_count', hue='body-style', data=grouped_data)
plt.title('Count of Vehicles by Engine and Body Style')
plt.xlabel('Engine')
plt.ylabel('Vehicle Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.legend(title='Body Style', loc='upper right', bbox_to_anchor=(1.2, 1))
plt.show()
# Out:
# Dataset according to company and body style is:
#
#    engine   body-style  vehicle_count
# 0    None        sedan              1
# 1    dohc  convertible              1
# 2    dohc    hatchback              1
# 3    dohc        sedan              2
# 4    dohc        wagon              1
# 5   dohcv    hatchback              1
# 6     ohc    hatchback             12
# 7     ohc        sedan             26
# 8     ohc        wagon              8
# 9    ohcf  convertible              1
# 10   ohcf      hardtop              1
# 11   ohcv      hardtop              1
# 12   ohcv        sedan              3
# 13  rotor    hatchback              1

# %%
# Grouping dataframe
# Grouping the data by 'company' and 'body-style', then calculate the count
grouped_data = df.groupby(['engine', 'body-style','mileage']).size().reset_index()
print("Dataset according to company and body style is:\n")
print(grouped_data,"\n")

# Plotting according to engine and body style
plt.figure(figsize=(12, 6))
sns.barplot(x='engine', y='mileage', hue='body-style', data=grouped_data)
plt.title('Count of Vehicles by Engine and Body Style')
plt.xlabel('Engine')
plt.ylabel('Vehicle Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.legend(title='Body Style', loc='upper right', bbox_to_anchor=(1.2, 1))
plt.show()
# Out:
# Dataset according to company and body style is:
#
#    engine   body-style  mileage  0
# 0    None        sedan       18  1
# 1    dohc  convertible       21  1
# 2    dohc    hatchback       19  1
# 3    dohc        sedan       15  2
# 4    dohc        wagon       19  1
# 5   dohcv    hatchback       17  1
# 6     ohc    hatchback       30  1
# 7     ohc    hatchback       31  7
# 8     ohc    hatchback       35  1
# 9     ohc    hatchback       37  1
# 10    ohc    hatchback       38  1
# 11    ohc    hatchback       47  1
# 12    ohc        sedan       15  1
# 13    ohc        sedan       16  2
# 14    ohc        sedan       19  1
# 15    ohc        sedan       21  1
# 16    ohc        sedan       22  1
# 17    ohc        sedan       23  3
# 18    ohc        sedan       24  3
# 19    ohc        sedan       25  3
# 20    ohc        sedan       26  1
# 21    ohc        sedan       27  1
# 22    ohc        sedan       31  3
# 23    ohc        sedan       37  2
# ...

# %%
# Plotting according to engine and body style
plt.figure(figsize=(12, 6))
sns.boxplot(x='engine', y='mileage', hue='body-style', data=grouped_data)
plt.title('Count of Vehicles by Engine and Body Style')
plt.xlabel('Engine')
plt.ylabel('Vehicle Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.legend(title='Body Style', loc='upper right', bbox_to_anchor=(1.2, 1))
plt.show()

# %%
# Grouping the data by 'company' and 'body-style', then calculate the count
grouped_data = df.groupby(['sunroof', 'body-style']).size().reset_index(name='vehicle_count')
print("Dataset according to Sunroof and body style is:\n")
print(grouped_data)
# Out:
# Dataset according to Sunroof and body style is:
#
#   sunroof   body-style  vehicle_count
# 0      No  convertible              1
# 1      No    hatchback              8
# 2      No        sedan             11
# 3      No        wagon              7
# 4     Yes  convertible              1
# 5     Yes      hardtop              2
# 6     Yes    hatchback              7
# 7     Yes        sedan             21
# 8     Yes        wagon              2

# %%
# Plotting according to Sunroof and count of vehicles produced
plt.figure(figsize=(12, 6))
sns.barplot(x='sunroof', y='vehicle_count', hue='body-style', data=grouped_data)
plt.title('Count of Vehicles by Sunroof and Body Style')
plt.xlabel('Sunroof')
plt.ylabel('Vehicle Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.legend(title='Body Style', loc='upper right', bbox_to_anchor=(1.2, 1))
plt.show()

# %%
# Grouping the data by 'company' and 'body-style', then calculate the count
grouped_data = df.groupby(['sunroof', 'company']).size().reset_index(name='vehicle_count')
print("Dataset according to Sunroof and body style is:\n")
print(grouped_data)
# Out:
# Dataset according to Sunroof and body style is:
#
#    sunroof        company  vehicle_count
# 0       No    alfa-romero              2
# 1       No      chevrolet              3
# 2       No          dodge              2
# 3       No          honda              3
# 4       No          isuzu              3
# 5       No         nissan              5
# 6       No         toyota              7
# 7       No          volvo              2
# 8      Yes           audi              4
# 9      Yes            bmw              6
# 10     Yes         jaguar              3
# 11     Yes          mazda              5
# 12     Yes  mercedes-benz              4
# 13     Yes     mitsubishi              4
# 14     Yes        porsche              3
# 15     Yes     volkswagen              4

# %%
# Plotting according to Sunroof and count of vehicles produced
plt.figure(figsize=(12, 6))
sns.barplot(x='sunroof', y='vehicle_count', hue='company', data=grouped_data)
plt.title('Count of Vehicles by Sunroof and Company')
plt.xlabel('Sunroof')
plt.ylabel('Vehicle Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.legend(title='Company', loc='upper right', bbox_to_anchor=(1.2, 1))
plt.show()

# %% [markdown]
# # Conclusions:
#
# # 1. Length and Mileage
#    -  ## 1.1 The lesser the length of the car,the more will be the mileage and vice versa.
#    - ## 1.2 This implies that smaller/compact cars gives more mileage(fuel economy) while larger cars gives lesser mileage.
#    - ## 1.3 The highest mileage is given by ohc engine.
#
# # 2. Sunroof
#   - ## 2.1 Most longer cars have sunroof while smaller or compact cars do not have sunroof.
#   - ## 2.2 Also few cars are there which gives good mileage , are compact and also have sunroof.
#   - ## 2.3 Their is no strong relation between cars having sunroof on mileage.
#
# # 3. body-style
#   - ## 3.1 Hatchback usually come in compact(smaller) size giving good mileage while sedan and wagon provide the most variation as they come in both smaller and larger length cars and also gives good mileage.
#   - ## 3.2 Convertible also gives good mileage in medium length
#   - ## 3.3 hardtop usually comes in longer length and lesser mileage
#
# # 4. company
#   - ## 4.1 Sedan is the most popular body style and is manufactured by most companies from luxury brands to normal brands
#   - ## 4.2 convertible and hardtop is manufactured by few companies as they are mostly luxury vehicles made by high end companies like porsche or mercedes.
#
# # Thus we can see that sedan body-style gives the most features like compact size, good mileage and sunroof.
